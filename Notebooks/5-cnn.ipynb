# %%
# !pip install gdown
# !pip install keras_tuner
# Out:
# Requirement already satisfied: gdown in /opt/conda/lib/python3.10/site-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from gdown) (3.15.1)
# Requirement already satisfied: requests[socks] in /opt/conda/lib/python3.10/site-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from gdown) (4.66.4)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (2024.8.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: keras_tuner in /opt/conda/lib/python3.10/site-packages (1.4.7)
# Requirement already satisfied: keras in /opt/conda/lib/python3.10/site-packages (from keras_tuner) (3.3.3)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from keras_tuner) (21.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from keras_tuner) (2.32.3)
# Requirement already satisfied: kt-legacy in /opt/conda/lib/python3.10/site-packages (from keras_tuner) (1.0.5)
# Requirement already satisfied: absl-py in /opt/conda/lib/python3.10/site-packages (from keras->keras_tuner) (1.4.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from keras->keras_tuner) (1.26.4)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from keras->keras_tuner) (13.7.1)
# Requirement already satisfied: namex in /opt/conda/lib/python3.10/site-packages (from keras->keras_tuner) (0.0.8)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.10/site-packages (from keras->keras_tuner) (3.11.0)
# Requirement already satisfied: optree in /opt/conda/lib/python3.10/site-packages (from keras->keras_tuner) (0.11.0)
# Requirement already satisfied: ml-dtypes in /opt/conda/lib/python3.10/site-packages (from keras->keras_tuner) (0.3.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->keras_tuner) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->keras_tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->keras_tuner) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->keras_tuner) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->keras_tuner) (2024.8.30)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from optree->keras->keras_tuner) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras->keras_tuner) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras->keras_tuner) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras->keras_tuner) (0.1.2)

# %%
import gdown  
import numpy as np
import pandas as pd
import requests
import matplotlib.pyplot as plt

from io import StringIO
from sklearn.preprocessing import LabelEncoder
from sklearn.cluster import DBSCAN
from sklearn.manifold import TSNE
from sklearn.metrics import roc_auc_score, roc_curve, recall_score, precision_score, confusion_matrix
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, Dense, Flatten, Dropout, Reshape, MaxPooling2D, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import ResNet50

import keras
import keras_tuner as kt  # Simplified import for keras_tuner
from keras_tuner.tuners import RandomSearch, BayesianOptimization
import seaborn as sns

hp = kt.HyperParameters()

# %% [markdown]
# # DATA UPLOAD AND PREPROCESSING

# %%
url = 'https://drive.google.com/uc?id=1f8wwVmV4JXc-iT4UH-RlYxTPQ0a1OFuj'
# filename
output = 'public_data.npz'
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1f8wwVmV4JXc-iT4UH-RlYxTPQ0a1OFuj
# From (redirected): https://drive.google.com/uc?id=1f8wwVmV4JXc-iT4UH-RlYxTPQ0a1OFuj&confirm=t&uuid=4b5b37fc-236c-40f0-8a04-19e08a3e720e
# To: /kaggle/working/public_data.npz
# 100%|██████████| 575M/575M [00:03<00:00, 169MB/s]
# 'public_data.npz'

# %%
# Separate the images and the labels
dataset = np.load('public_data.npz', allow_pickle=True)
images = dataset["data"]
labels = dataset["labels"]
encoder = LabelEncoder()
encoder.fit(labels)
encoded_labels = encoder.transform(labels)
labels = np.unique(dataset["labels"], return_inverse=True)[1]

# %%
unique_elements, counts_elements = np.unique(labels, return_counts=True)

print("zero images: %d\n one images: %d" % (counts_elements[0], counts_elements[1]))
# Out:
# zero images: 3199
#  one images: 2001

# %%
# Normalize the images to the range [0, 1]
if images.max() > 1:  # Check if normalization is needed
    images = images / 255.0  # Normalize all images

# %%
plt.imshow(images[1], interpolation='nearest')
plt.show()

# %%
# Display a sample of images from the dataset
num_img = 10
fig, axes = plt.subplots(1, num_img, figsize=(20, 20))

# Iterate through the selected number of images
for i in range(num_img):
    idx = np.random.randint(len(images))
    ax = axes[i % num_img]
    ax.imshow(images[idx])
    ax.set_title('{}'.format(labels[idx]))

# Adjust layout and display the images
plt.tight_layout()
plt.show()

# %%
# Cleaning the Dataset
flattened_images = images.reshape(images.shape[0], -1)
db = DBSCAN(eps=0.1, min_samples=10).fit(flattened_images)
labelss = db.labels_
n_clusters_ = len(set(labelss)) - (1 if -1 in labelss else 0)
n_noise_ = list(labelss).count(-1)
unique_elements, counts_elements = np.unique(labelss, return_counts=True)
print("  plants cluster: %d\n   shrek cluster:  %d\n    meme cluster:  %d" % (counts_elements[0], counts_elements[1], counts_elements[2]))
# Out:
#   plants cluster: 5004
#    shrek cluster:  98
#     meme cluster:  98

# %%
# t-SNE PLOTTING

# Reduce the dimensionality of the images to 2 components for 2D plotting
tsne = TSNE(n_components=2, perplexity=30, n_iter=300)
tsne_results = tsne.fit_transform(flattened_images)

# Define the colors for each cluster
cluster_colors = { -1: 'green', 0: 'brown', 1: 'blue'}

# Plot each cluster using t-SNE results
for cluster_label in np.unique(labelss):
    # Select the data points that belong to the current cluster
    in_cluster = labelss == cluster_label
    cluster_data = tsne_results[in_cluster]

    # Plot those data points with the cluster's color
    plt.scatter(cluster_data[:, 0], cluster_data[:, 1],
                c=cluster_colors[cluster_label], label=f'Cluster {cluster_label}', alpha=0.5)

# Label the axes and show the plot
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.title('Clusters in 2D with t-SNE')
plt.legend()
plt.show()

# %%
# Masking
cluster_good_indices = np.where(labelss == -1)[0]
mask = np.zeros(len(labels), dtype=bool)
mask[cluster_good_indices] = True

# Apply the mask to both labels and images.
labels = labels[mask]
images = images[mask]

# %%
# Splitting in train test and validation
trainD, tempD, trainL, tempL = train_test_split(images, labels, test_size=0.20, random_state=42)
valD, testD, valL, testL = train_test_split(tempD, tempL, test_size=0.50, random_state=42)

# Now you have train, validation, and test sets
print("Training Data Shape:", trainD.shape)
print("Validation Data Shape:", valD.shape)
print("Test Data Shape:", testD.shape)
# Out:
# Training Data Shape: (4002, 96, 96, 3)
# Validation Data Shape: (500, 96, 96, 3)
# Test Data Shape: (501, 96, 96, 3)

# %% [markdown]
# # HP TUNING THROUGH KERAS TUNER

# %%
class MyHyperModel(kt.HyperModel):
    def build(self, hp):
        M = keras.Sequential()
        M.add(keras.Input(shape=(96, 96, 3)))
        num_conv_layers = hp.Int("conv_layers", min_value=1, max_value=4)
        for i in range(num_conv_layers):
            # Tune the number of filters for each Conv2D layer
            filters = hp.Int(f"filters_{i}", min_value=16, max_value=128, step=16)
            # Tune the kernel size for each Conv2D layer
            kernel_size = hp.Choice(f"kernel_size_{i}", values=[3, 5, 7])
            M.add(keras.layers.Conv2D(filters, kernel_size=(kernel_size, kernel_size), activation="relu"))
            M.add(keras.layers.MaxPooling2D(pool_size=(2, 2)))
        M.add(keras.layers.Flatten())
        for i in range(3):
            M.add(keras.layers.Dense(units=700, activation='relu'))
        M.add(keras.layers.Dense(1, activation='sigmoid'))
        learning_rate = hp.Float("learning_rate", min_value=1e-5, max_value=1e-2, sampling="log")
        opt = keras.optimizers.Adam(learning_rate=learning_rate)
        M.compile(loss="binary_crossentropy", optimizer=opt, metrics=["accuracy"])
        return M

    def fit(self, hp, M, x, y, xy_val, **kwargs):
        factor = 0.1717
        reduce_cb = keras.callbacks.ReduceLROnPlateau(monitor='val_accuracy', factor=factor, patience=5, 
                                                      min_delta=1e-4, min_lr=1e-5)
        early_cb = keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10, min_delta=1e-5)
        
        kwargs['callbacks'].extend([reduce_cb, early_cb])
        return M.fit(x, y, batch_size=128, epochs=100, validation_data=xy_val, **kwargs)

# %%
tuner = kt.BayesianOptimization(
 MyHyperModel(), 
 objective="val_accuracy", 
 max_trials=10,
 overwrite=True, 
 directory="/tmp", 
 project_name="plant", 
)

tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 4
# conv_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 1, 'max_value': 4, 'step': 1, 'sampling': 'linear'}
# filters_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 128, 'step': 16, 'sampling': 'linear'}
# kernel_size_0 (Choice)
# {'default': 3, 'conditions': [], 'values': [3, 5, 7], 'ordered': True}
# learning_rate (Float)
# {'default': 1e-05, 'conditions': [], 'min_value': 1e-05, 'max_value': 0.01, 'step': None, 'sampling': 'log'}

# %%
tuner.search(trainD, trainL, (valD, valL))
# Out:
# Trial 10 Complete [00h 00m 02s]
#
# Best val_accuracy So Far: 0.7379999756813049
# Total elapsed time: 00h 06m 14s

# %%
tuner.results_summary(num_trials=4)
# Out:
# Results summary
# Results in /tmp/plant
# Showing 4 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 02 summary
# Hyperparameters:
# conv_layers: 4
# filters_0: 16
# kernel_size_0: 3
# learning_rate: 0.00031121407316281845
# filters_1: 112
# kernel_size_1: 3
# filters_2: 16
# kernel_size_2: 3
# filters_3: 16
# kernel_size_3: 3
# Score: 0.7379999756813049
#
# Trial 00 summary
# Hyperparameters:
# conv_layers: 3
# filters_0: 64
# kernel_size_0: 7
# learning_rate: 0.0010154065942077095
# filters_1: 16
# kernel_size_1: 3
# filters_2: 16
# kernel_size_2: 3
# Score: 0.722000002861023
#
# Trial 01 summary
# Hyperparameters:
# conv_layers: 3
# filters_0: 64
# kernel_size_0: 5
# learning_rate: 0.00013233946627272026
# filters_1: 128
# kernel_size_1: 5
# filters_2: 16
# kernel_size_2: 3
# Score: 0.7099999785423279
#
# Trial 06 summary
# Hyperparameters:
# conv_layers: 2
# filters_0: 80
# kernel_size_0: 3
# learning_rate: 0.0001627229088511537
# filters_1: 16
# kernel_size_1: 3
# filters_2: 48
# kernel_size_2: 7
# filters_3: 48
# kernel_size_3: 5
# Score: 0.7099999785423279

# %%
best_hp = tuner.get_best_hyperparameters(num_trials=1)[0]

# %%
print("Best Hyperparameters:")
for hp_name, hp_value in best_hp.values.items():
    print(f"{hp_name}: {hp_value}")
# Out:
# Best Hyperparameters:
# conv_layers: 4
# filters_0: 16
# kernel_size_0: 3
# learning_rate: 0.00031121407316281845
# filters_1: 112
# kernel_size_1: 3
# filters_2: 16
# kernel_size_2: 3
# filters_3: 16
# kernel_size_3: 3

# %% [markdown]
# # MODEL

# %%
M = MyHyperModel().build(best_hp)

# %%
M.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)               │ (None, 94, 94, 16)     │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 47, 47, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 45, 45, 112)    │        16,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 22, 22, 112)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 20, 20, 16)     │        16,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 10, 10, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 8, 8, 16)       │         2,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 4, 4, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 700)            │       179,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 700)            │       490,700 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 700)            │       490,700 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │           701 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,197,153 (4.57 MB)
#  Trainable params: 1,197,153 (4.57 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
H = MyHyperModel().fit(
    best_hp,         
    M,                
    trainD,           
    trainL,          
    xy_val=(valD, valL),   
    callbacks=[]
)
# Out:
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 88ms/step - accuracy: 0.5996 - loss: 0.6754 - val_accuracy: 0.6200 - val_loss: 0.6655 - learning_rate: 3.1121e-04
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.6176 - loss: 0.6684 - val_accuracy: 0.6200 - val_loss: 0.6554 - learning_rate: 3.1121e-04
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.6171 - loss: 0.6582 - val_accuracy: 0.6200 - val_loss: 0.6533 - learning_rate: 3.1121e-04
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.6326 - loss: 0.6416 - val_accuracy: 0.6360 - val_loss: 0.6402 - learning_rate: 3.1121e-04
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.6605 - loss: 0.6188 - val_accuracy: 0.6360 - val_loss: 0.6252 - learning_rate: 3.1121e-04
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.6662 - loss: 0.6107 - val_accuracy: 0.6300 - val_loss: 0.6422 - learning_rate: 3.1121e-04
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.6828 - loss: 0.5885 - val_accuracy: 0.6760 - val_loss: 0.5846 - learning_rate: 3.1121e-04
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.7117 - loss: 0.5536 - val_accuracy: 0.6940 - val_loss: 0.5727 - learning_rate: 3.1121e-04
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.7400 - loss: 0.5138 - val_accuracy: 0.6880 - val_loss: 0.5769 - learning_rate: 3.1121e-04
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.7472 - loss: 0.4990 - val_accuracy: 0.6880 - val_loss: 0.5768 - learning_rate: 3.1121e-04
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.7790 - loss: 0.4530 - val_accuracy: 0.7000 - val_loss: 0.5996 - learning_rate: 3.1121e-04
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.8280 - loss: 0.3980 - val_accuracy: 0.6580 - val_loss: 0.6891 - learning_rate: 3.1121e-04
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.8151 - loss: 0.3851 - val_accuracy: 0.6980 - val_loss: 0.6208 - learning_rate: 3.1121e-04
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.8674 - loss: 0.3106 - val_accuracy: 0.5940 - val_loss: 0.8224 - learning_rate: 3.1121e-04
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.8799 - loss: 0.2815 - val_accuracy: 0.6820 - val_loss: 0.8196 - learning_rate: 3.1121e-04
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.8949 - loss: 0.2483 - val_accuracy: 0.6720 - val_loss: 0.8150 - learning_rate: 3.1121e-04
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9634 - loss: 0.1328 - val_accuracy: 0.6680 - val_loss: 0.8617 - learning_rate: 5.3435e-05
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9696 - loss: 0.1144 - val_accuracy: 0.6740 - val_loss: 0.9038 - learning_rate: 5.3435e-05
# Epoch 19/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9741 - loss: 0.0962 - val_accuracy: 0.6780 - val_loss: 0.9440 - learning_rate: 5.3435e-05
# Epoch 20/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9818 - loss: 0.0835 - val_accuracy: 0.6660 - val_loss: 0.9982 - learning_rate: 5.3435e-05
# Epoch 21/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9858 - loss: 0.0745 - val_accuracy: 0.6820 - val_loss: 1.0222 - learning_rate: 5.3435e-05

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 6))
xx = np.arange(1, len(H.history['loss']) + 1)
# Plot 1: Loss
ax = axes[0]
ax.plot(xx, H.history['loss'], color='royalblue', linewidth=2)
ax.grid(True, linestyle='--', alpha=0.6)
ax.set_xlabel('Epoch', fontsize=12)
ax.set_ylabel('Loss', fontsize=12)
ax.set_title('Training Loss Over Epochs', fontsize=14)
ax.set_xticks(np.linspace(1, len(H.history['loss']), 10, dtype=int))
# Plot 2: Accuracy
ax = axes[1]
ax.plot(xx, H.history['accuracy'], color='seagreen', linewidth=2)
ax.grid(True, linestyle='--', alpha=0.6)
ax.set_xlabel('Epoch', fontsize=12)
ax.set_ylabel('Accuracy', fontsize=12)
ax.set_title('Training Accuracy Over Epochs', fontsize=14)
ax.set_xticks(np.linspace(1, len(H.history['accuracy']), 10, dtype=int))

plt.tight_layout()
plt.show()

# %%
 # Evaluate model
trainLoss, trainAccuracy = M.evaluate(trainD, trainL, verbose=False)
valLoss, valAccuracy = M.evaluate(valD, valL, verbose=False)
testLoss, testAccuracy = M.evaluate(testD, testL, verbose=False)
# Print the results
print(f"Training Loss: {trainLoss:.4f}, Training Accuracy: {trainAccuracy:.4f}")
print(f"Validation Loss: {valLoss:.4f}, Validation Accuracy: {valAccuracy:.4f}")
print(f"Test Loss: {testLoss:.4f}, Test Accuracy: {testAccuracy:.4f}")
# Out:
# Training Loss: 0.0670, Training Accuracy: 0.9870
# Validation Loss: 1.0222, Validation Accuracy: 0.6820
# Test Loss: 1.1706, Test Accuracy: 0.6667

# %%
predictions = M.predict(testD)
predicted_classes = (predictions > 0.5).astype(int).flatten()
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
# Compute the confusion matrix
cm = confusion_matrix(testL, predicted_classes)

# Visualize the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=np.unique(testL), 
            yticklabels=np.unique(testL))
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
